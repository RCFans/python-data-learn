# %%
import pandas as pd

# %%
path = 'data/iris.data'

# %%
open(path).readline()
# Out:
# '5.1,3.5,1.4,0.2,Iris-setosa\n'

# %%
attributes = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']
iris = pd.read_table(path, sep=',', header=None, names=attributes)

# %%
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_classes = iris['class']
iris_classes = iris_classes.unique()
for iris_class in iris_classes:
    print(iris_class)
# Out:
# Iris-setosa
# Iris-versicolor
# Iris-virginica

# %%
# iris_setosa = iris[iris['class'] == 'Iris-setosa']
# iris_setosa.tail()

irisObjects = {}
for iris_class in iris_classes:
    irisObjects[iris_class] = iris[iris['class'] == iris_class]

# %%
iris_classes[0]
# Out:
# 'Iris-setosa'

# %%
setosa_sepal_length = irisObjects[iris_classes[0]]['sepal length']
setosa_sepal_width = irisObjects[iris_classes[0]]['sepal width']
versicolor_sepal_length = irisObjects[iris_classes[1]]['sepal length']
versicolor_sepal_width = irisObjects[iris_classes[1]]['sepal width']
virginica_sepal_length = irisObjects[iris_classes[2]]['sepal length']
virginica_sepal_width = irisObjects[iris_classes[2]]['sepal width']
plt.scatter(setosa_sepal_length, setosa_sepal_width,  color='green')
plt.scatter(versicolor_sepal_length, versicolor_sepal_width,  color='blue')
plt.scatter(virginica_sepal_length, virginica_sepal_width,  color='red')

# %%
setosa_petal_length = irisObjects[iris_classes[0]]['petal length']
setosa_petal_width = irisObjects[iris_classes[0]]['petal width']
versicolor_petal_length = irisObjects[iris_classes[1]]['petal length']
versicolor_petal_width = irisObjects[iris_classes[1]]['petal width']
virginica_petal_length = irisObjects[iris_classes[2]]['petal length']
virginica_petal_width = irisObjects[iris_classes[2]]['petal width']
plt.scatter(setosa_petal_length, setosa_petal_width,  color='green')
plt.scatter(versicolor_petal_length, versicolor_petal_width,  color='red', marker='s', 
            label='versicolor')
plt.scatter(virginica_petal_length, virginica_petal_width,  color='blue', marker='d')

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %%
print(iris.data[2])
# Out:
# [ 4.7  3.2  1.3  0.2]

# %%
iris.data.shape
# Out:
# (150, 4)

# %%
iris_X = iris.data
iris_y = iris.target
np.unique(iris_Y)
# Out:
# array([0, 1, 2])

# %%
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]
# Create and fit a nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(iris_X_train, iris_y_train) 
KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
               metric_params=None, n_neighbors=5, p=2, weights='uniform')
knn.predict(iris_X_test)
array([1, 2, 1, 0, 0, 0, 2, 1, 2, 0])
iris_y_test
# Out:
# array([1, 1, 1, 0, 0, 0, 2, 1, 2, 0])

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

n_neighbors = 15

# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features. We could
                      # avoid this ugly slicing by using a two-dim dataset
y = iris.target

h = .02  # step size in the mesh

# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

for weights in ['uniform', 'distance']:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, m_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("3-Class classification (k = %i, weights = '%s')"
              % (n_neighbors, weights))
# Out:
# Automatically created module for IPython interactive environment

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets

n_neighbors = 15

# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, -2:]  # we only take the first two features. We could
                      # avoid this ugly slicing by using a two-dim dataset
y = iris.target

h = .02  # step size in the mesh

# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

for weights in ['uniform', 'distance']:
    # we create an instance of Neighbours Classifier and fit the data.
    clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
    clf.fit(X, y)

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, m_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("3-Class classification (k = %i, weights = '%s')"
              % (n_neighbors, weights))
# Out:
# Automatically created module for IPython interactive environment
